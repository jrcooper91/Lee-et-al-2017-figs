# %%
import pyfits 
import matplotlib.pyplot as plt
import numpy as np

# %%
pyfits.info("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30737.1D.fits")
header_primary = pyfits.getheader("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30737.1D.fits")
header_primary
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30737.1D.fits",'bitpix',1)
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30737.1D.fits",'xtension',1)
data_table, header_table = pyfits.getdata("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30737.1D.fits",1, header=True)
w = data_table.field('wave')
f = data_table.field('flux')
w_rest = w/(1+1.726)
pyfits.info("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits")
header_primarya = pyfits.getheader("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits")
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits",'bitpix',1)
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits",'xtension',1)
data_tablea, header_tablea = pyfits.getdata("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits",1, header=True)
wa = data_tablea.field('wave')
fa = data_tablea.field('flux')
w_resta = wa/(1+1.726)
# Out:
# Filename: /Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30737.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     35   312R x 7C    [D, D, D, D, D, D, D]
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     35   360R x 7C    [D, D, D, D, D, D, D]

# %%
pyfits.info("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_33092.1D.fits")
header_primary1 = pyfits.getheader("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_33092.1D.fits")
header_primary1
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_33092.1D.fits",'bitpix',1)
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_33092.1D.fits",'xtension',1)
data_table1, header_table1 = pyfits.getdata("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_33092.1D.fits",1, header=True)
w1 = data_table1.field('wave')
f1 = data_table1.field('flux')
w_rest1 = w1/(1+1.66390)
pyfits.info("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits")
header_primaryb = pyfits.getheader("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits")
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits",'bitpix',1)
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits",'xtension',1)
data_tableb, header_tableb = pyfits.getdata("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits",1, header=True)
wb = data_tableb.field('wave')
fb = data_tableb.field('flux')
w_restb = wb/(1+1.66390)
# Out:
# Filename: /Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_33092.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     35   312R x 7C    [D, D, D, D, D, D, D]
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     35   360R x 7C    [D, D, D, D, D, D, D]

# %%
pyfits.info("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30545.1D.fits")
header_primary2 = pyfits.getheader("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30545.1D.fits")
header_primary2
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30545.1D.fits",'bitpix',1)
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30545.1D.fits",'xtension',1)
data_table2, header_table2 = pyfits.getdata("/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30545.1D.fits",1, header=True)
w2 = data_table2.field('wave')
f2 = data_table2.field('flux')
w_rest2 = w2/(1+1.65280)
pyfits.info("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits")
header_primaryc = pyfits.getheader("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits")
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits",'bitpix',1)
pyfits.getval("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits",'xtension',1)
data_tablec, header_tablec = pyfits.getdata("/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits",1, header=True)
wc = data_tablec.field('wave')
fc = data_tablec.field('flux')
w_restc = wc/(1+1.65280)
# Out:
# Filename: /Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30545.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     35   312R x 7C    [D, D, D, D, D, D, D]
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     35   360R x 7C    [D, D, D, D, D, D, D]

# %%
plt.subplot(311)
#plt.xlim(3000, 6850)
#plt.ylim(0, 0.5)
plt.ylabel('F$_\lambda$')
plt.plot(w_rest,f)
plt.plot(w_resta,fa)
plt.subplot(312)
plt.plot(w_rest1,f1)
plt.plot(w_restb,fb)
plt.subplot(313)
plt.plot(w_rest2,f2)
plt.plot(w_restc,fc)
plt.xlabel('Angstroms \lambda$_Rest$')
plt.show()
