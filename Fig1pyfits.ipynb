# %%
import pyfits 
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# %%
g30737=plt.subplot(311)

image=fits.open('/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.new_zfit.fits')
image.info()
cont1d=image[3].data
cont1d=np.array(cont1d)
line1d=image[4].data
line1d=np.array(line1d)


image2=fits.open('/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits')
image2.info()
image2data=image2[1].data
wavelength=np.array(image2data.field(0))
#correct for redshift
wavelength=wavelength/(1+1.621)
flux=np.array(image2data.field(1))
contam=np.array(image2data.field(3))
sensitivity=np.array(image2data.field(6))
flux=(flux-contam)/sensitivity
totalmodel=(line1d+cont1d)/sensitivity

image4=fits.open('/Users/jennifercooper/Downloads/for_jenn/uds-18/ZFIT/FITS/uds-18-G141_30737.new_zfit.fits')
image4.info()
cont1d4=image4[3].data
cont1d4=np.array(cont1d4)
line1d4=image4[4].data
line1d4=np.array(line1d4)

image3=fits.open('/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30737.1D.fits')
image3.info()
image3data=image3[1].data
wavelength2=np.array(image3data.field(0))
#correct for redshift
wavelength2=wavelength2/(1+1.621)
flux2=np.array(image3data.field(1))
contam2=np.array(image3data.field(3))
sensitivity2=np.array(image3data.field(6))
flux2=(flux2-contam2)/sensitivity2
totalmodel2=(line1d4+cont1d4)/sensitivity2
# Out:
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.new_zfit.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      36   ()
#   1  CONT2D      ImageHDU        21   (360, 30)   float64
#   2  LINE2D      ImageHDU        21   (360, 30)   float64
#   3  CONT1D      ImageHDU         7   (360,)   float64
#   4  LINE1D      ImageHDU         7   (360,)   float64
#   5  COEFFS      ImageHDU         7   (10,)   float64
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30737.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU       4   ()
#   1              BinTableHDU     35   360R x 7C   [D, D, D, D, D, D, D]
# Filename: /Users/jennifercooper/Downloads/for_jenn/uds-18/ZFIT/FITS/uds-18-G141_30737.new_zfit.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      36   ()
# ...

# %%
g33092=plt.subplot(312)

imagea=fits.open('/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.new_zfit.fits')
imagea.info()
cont1da=imagea[3].data
cont1da=np.array(cont1da)
line1da=imagea[4].data
line1da=np.array(line1da)


image2a=fits.open('/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits')
image2a.info()
image2dataa=image2a[1].data
wavelengtha=np.array(image2dataa.field(0))
#correct for redshift
wavelengtha=wavelengtha/(2.621)
fluxa=np.array(image2dataa.field(1))
contama=np.array(image2dataa.field(3))
sensitivitya=np.array(image2dataa.field(6))
fluxa=(fluxa-contama)/sensitivitya
totalmodela=(line1da+cont1da)/sensitivitya

image4a=fits.open('/Users/jennifercooper/Downloads/for_jenn/uds-18/ZFIT/FITS/uds-18-G141_33092.new_zfit.fits')
image4a.info()
cont1d4a=image4a[3].data
cont1d4a=np.array(cont1d4a)
line1d4a=image4a[4].data
line1d4a=np.array(line1d4a)

image3a=fits.open('/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_33092.1D.fits')
image3a.info()
image3dataa=image3a[1].data
wavelength2a=np.array(image3dataa.field(0))
#correct for redshift
wavelength2a=wavelength2a/(2.621)
flux2a=np.array(image3dataa.field(1))
contam2a=np.array(image3dataa.field(3))
sensitivity2a=np.array(image3dataa.field(6))
flux2a=(flux2a-contam2a)/sensitivity2a
totalmodel2a=(line1d4a+cont1d4a)/sensitivity2a
# Out:
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.new_zfit.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      41   ()
#   1  CONT2D      ImageHDU        21   (360, 27)   float64
#   2  LINE2D      ImageHDU        21   (360, 27)   float64
#   3  CONT1D      ImageHDU         7   (360,)   float64
#   4  LINE1D      ImageHDU         7   (360,)   float64
#   5  COEFFS      ImageHDU         7   (10,)   float64
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_33092.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU       4   ()
#   1              BinTableHDU     35   360R x 7C   [D, D, D, D, D, D, D]
# Filename: /Users/jennifercooper/Downloads/for_jenn/uds-18/ZFIT/FITS/uds-18-G141_33092.new_zfit.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      36   ()
# ...

# %%
g30545=plt.subplot(313)

imageb=fits.open('/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.new_zfit.fits')
imageb.info()
cont1db=imageb[3].data
cont1db=np.array(cont1db)
line1db=imageb[4].data
line1db=np.array(line1db)


image2b=fits.open('/Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits')
image2b.info()
image2datab=image2b[1].data
wb=np.array(image2datab.field(0))
#correct for redshift
wb=wb/(1+1.624)
fb=np.array(image2datab.field(1))
contamb=np.array(image2datab.field(3))
sensitivityb=np.array(image2datab.field(6))
fb=(fb-contamb)/sensitivityb
totmodelb=(line1db+cont1db)/sensitivityb

image4b=fits.open('/Users/jennifercooper/Downloads/for_jenn/uds-18/ZFIT/FITS/uds-18-G141_30545.new_zfit.fits')
image4b.info()
cont1d4b=image4b[3].data
cont1d4b=np.array(cont1d4b)
line1d4b=image4b[4].data
line1d4b=np.array(line1d4b)

image3b=fits.open('/Users/jennifercooper/Downloads/for_jenn/uds-18/1D/FITS/uds-18-G141_30545.1D.fits')
image3b.info()
image3datab=image3b[1].data
w2b=np.array(image3datab.field(0))
#correct for redshift
w2b=w2b/(1+1.624)
f2b=np.array(image3datab.field(1))
contam2b=np.array(image3datab.field(3))
sensitivity2b=np.array(image3datab.field(6))
f2=(f2b-contam2b)/sensitivity2b
totmodel2b=(line1d4b+cont1d4b)/sensitivity2b
# Out:
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.new_zfit.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      41   ()
#   1  CONT2D      ImageHDU        21   (360, 29)   float64
#   2  LINE2D      ImageHDU        21   (360, 29)   float64
#   3  CONT1D      ImageHDU         7   (360,)   float64
#   4  LINE1D      ImageHDU         7   (360,)   float64
#   5  COEFFS      ImageHDU         7   (10,)   float64
# Filename: /Users/jennifercooper/Downloads/for_jenn/g102/IRC0218A-G102_30545.1D.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU       4   ()
#   1              BinTableHDU     35   360R x 7C   [D, D, D, D, D, D, D]
# Filename: /Users/jennifercooper/Downloads/for_jenn/uds-18/ZFIT/FITS/uds-18-G141_30545.new_zfit.fits
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU      36   ()
# ...

# %%
#30737
plt.subplot(311)
g30737.plot(wavelength[np.where(wavelength>3000.0)[-1][1]:np.where(wavelength<4300.0)[-1][-1]],
           flux[np.where(wavelength>3000.0)[-1][1]:np.where(wavelength<4300.0)[-1][-1]],color='purple')
g30737.plot(wavelength2[np.where(wavelength2>4100.0)[-1][1]:np.where(wavelength2<6400.0)[-1][-1]],
           flux2[np.where(wavelength2>4100.0)[-1][1]:np.where(wavelength2<6400.0)[-1][-1]],color='red')
g30737.plot(wavelength2[np.where(wavelength2>4100.0)[-1][1]:np.where(wavelength2<6400.0)[-1][-1]],
           totalmodel2[np.where(wavelength2>4100.0)[-1][1]:np.where(wavelength2<6400.0)[-1][-1]],
            linewidth=3.0, color='Black')
g30737.plot(wavelength[np.where(wavelength>3000.0)[-1][1]:np.where(wavelength<4360.0)[-1][-1]],
           totalmodel[np.where(wavelength>3000.0)[-1][1]:np.where(wavelength<4360.0)[-1][-1]],
            linewidth=3.0,color='Black')
#33092
plt.subplot(312)
g33092.plot(wavelengtha[np.where(wavelengtha>3000.0)[-1][1]:np.where(wavelengtha<4300.0)[-1][-1]],
           fluxa[np.where(wavelengtha>3000.0)[-1][1]:np.where(wavelengtha<4300.0)[-1][-1]],color='purple')
g33092.plot(wavelength2a[np.where(wavelength2a>4100.0)[-1][1]:np.where(wavelength2a<6400.0)[-1][-1]],
           flux2a[np.where(wavelength2a>4100.0)[-1][1]:np.where(wavelength2a<6400.0)[-1][-1]],color='red')
g33092.plot(wavelength2a[np.where(wavelength2a>4100.0)[-1][1]:np.where(wavelength2a<6400.0)[-1][-1]],
           totalmodel2a[np.where(wavelength2a>4100.0)[-1][1]:np.where(wavelength2a<6400.0)[-1][-1]],linewidth=3.0, color='Black')
g33092.plot(wavelengtha[np.where(wavelengtha>3000.0)[-1][1]:np.where(wavelengtha<4360.0)[-1][-1]],
           totalmodela[np.where(wavelengtha>3000.0)[-1][1]:np.where(wavelengtha<4360.0)[-1][-1]],linewidth=3.0,color='Black')

#30545
plt.subplot(313)
g30545.plot(wb[np.where(wb>3000.0)[-1][1]:np.where(wb<4300.0)[-1][-1]],
           fb[np.where(wb>3000.0)[-1][1]:np.where(wb<4300.0)[-1][-1]]
            ,color='purple')
g30545.plot(w2b[np.where(w2b>4100.0)[-1][1]:np.where(w2b<6400.0)[-1][-1]],
           f2b[np.where(w2b>4100.0)[-1][1]:np.where(w2b<6400.0)[-1][-1]],
            color='red')
g30545.plot(w2b[np.where(w2b>4100.0)[-1][1]:np.where(w2b<6400.0)[-1][-1]],
           totmodel2b[np.where(w2b>4100.0)[-1][1]:np.where(w2b<6400.0)[-1][-1]],
            linewidth=3.0, color='Black')
g30545.plot(wb[np.where(wb>3000.0)[-1][1]:np.where(wb<4360.0)[-1][-1]],
           totmodelb[np.where(wb>3000.0)[-1][1]:np.where(wb<4360.0)[-1][-1]],
            linewidth=3.0,color='Black')


plt.xlabel('Angstroms \lambda$_Rest$')



plt.show()
